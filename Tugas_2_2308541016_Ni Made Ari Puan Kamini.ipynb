# %%
rik_16 = print ("Siapakah biasmu di Enhypen?")
ar_16 = str(input("Biasku di Enhypen adalah : "))
kmn_16 = ['Jake adalah biasku']

print("")
print ("Biasmu di Enhypen adalah" ,ar_16, "dan", kmn_16)

# %%
#type 2.4
ari_16 = "Sim Jaeyun"
gender_16 = "laki-laki"
age_16 = "22 tahun"
kerja_16 = "Idol"
fc_16 = "Engene <3"
print (ari_16 + " adalah seorang " + gender_16 + " yang berumur " + age_16 + " bekerja sebagai seorang " + kerja_16 + " memiliki fansclub bernama " + fc_16 +"." )

print("")

# %%
ari_16 = input ("masukkan sebuah nama: ")
gender_16 = input("apa jenis kelamin anda?: ")
age_16 = int(input("berapa umur anda? (dalam tahun):"))
kerja_16 = str(input("apa pekerjaan anda?"))
print (f"{ari_16} adalah seorang {gender_16} berumur {age_16} tahun merupakan seorang {kerja_16} ." )

# %%
#type 2.5
puan_16 = "Hari ini adalah hari Rabu tanggal 20 Maret 2024"
print (puan_16 [0:9])
print (puan_16 [9:15])
print(puan_16 [15:25])
print (puan_16 [25:33])
print (puan_16[33:47])

# %%
puan_16 = "Hari ini adalah hari Rabu tanggal 20 Maret 2024"
pn_16 = int(input("Kamu mau angka ke berapa? : "))
pnk_16 = int(input("Dari berapa? : "))
print (puan_16 [pn_16: pnk_16])

# %%
#type 2.6
apk_16 = print("Sehabis sabtu itu minggu ya?")
hari_16 = "Sehabis sabtu itu minggu ya?"
print (len(hari_16))

#bulan_16 = "Maret"
#bulan_16.upper()

#tahun_16 = "DUA RIBU DUA PULUH EMPAT"
#tahun_16.lower()

#i_16 = str(input("kata apa yang ingin kamu cari?"))
#hari_16.find (i_16)

n_16 = str(input("kata apa yang ingin kamu ganti? :"))
p_16 = str(input("kamu ingin menggantinya dengan kata apa? :"))
hari_16.replace(n_16, p_16)

#print ('Sabtu' in hari_16)

# %%
#type 2.7
sisi_16= int(input("Panjang sisi persegi yang diketahui dalam cm adalah "))
luasPersegi = sisi_16*sisi_16
pnk_16 = print(luasPersegi , "cm^2")
apk_16 = print ("___________________________________________")
apk_16 = print(" |Selanjutnya kita akan menghitung uang ^^ |")
apk_16 = print ("___________________________________________")

apk_16 = print("Ayoo hitung jumlah uang yang ada didompet mu! Ini tidak termasuk uang direkeningmu ya..")
apk_16 = print ("Kalau kamu tidak memiliki lembar atau keping uang yang disebutkan bisa diisi 0 ya!")
kertas1k_16 = int(input("berapa lembar jumlah uang Rp 1.000 yang ada di dompetmu?"))
kertas2k_16 = int(input("berapa lembar jumlah uang Rp 2.000 yang ada di dompetmu?"))
kertas5k_16 = int(input("berapa lembar jumlah uang Rp 5.000 yang ada di dompetmu?"))
kertas10k_16 = int(input("berapa lembar jumlah uang Rp 10.000 yang ada di dompetmu?"))
kertas20k_16 = int(input("berapa lembar jumlah uang Rp 20.000 yang ada di dompetmu?"))
kertas50k_16 = int(input("berapa lembar jumlah uang Rp 50.000 yang ada di dompetmu?"))
kertas100k_16 = int(input("berapa lembar jumlah uang Rp 100.000 yang ada di dompetmu?"))

apk_16 = print ("")
apk_16 = print ("Uang kertas udah semua nih, sekarang ayoo hitung uang koinnya!")
apk_16 = print ("")

koin50_16 = int(input("berapa keping koin Rp 50 yang kamu miliki?"))
koin100_16 = int(input("berapa keping koin Rp 100 yang kamu miliki?"))
koin200_16 = int(input("berapa keping koin Rp 200 yang kamu miliki?"))
koin500_16 = int(input("berapa keping koin Rp 500 yang kamu miliki?"))
koin1k_16 = int(input("berapa keping koin Rp 1000 yang kamu miliki?"))

apk_16 = print("Data yang aku miliki sekarang sudah cukup nih, ayoo kita hitung!")
jumlahkertas_16 = kertas1k_16*1000 + kertas2k_16*2000 + kertas5k_16*5000 + kertas10k_16*10000 + kertas20k_16*20000 + kertas50k_16*50000 + kertas100k_16*100000
jumlahkoin_16 = koin50_16*50 + koin100_16*100 + koin200_16*200 + koin500_16*500 +koin1k_16*1000
jumlahtotal_16 = jumlahkertas_16 + jumlahkoin_16
apk_16 = print ("___________________________________________")
apk_16 = print("Jumlah uang yang ada di dalam dompetmu adalah: Rp ", jumlahtotal_16)

# %%
#type 2.8
A_16 = 2024

apk_16 = print("ayoo tebak perkalian yang memiliki hasil 2024 yuk!")
bil1_16 = int(input("ayoo masukan bilangan pertama: "))
bil2_16 = int(input("ayoo masukan bilangan kedua: "))
hasil_16 = bil1_16 * bil2_16 == A_16

kebenaran = print("Apakah jawabanmu benar? " , hasil_16)
apk_16 = print("")
apk_16 = print("coba operator perbandingan yang lainnya yuk!")
apk_16 = print("____________________________________________")
apk_16 = print("")

tb_16 = 156
apk_16 = print("Apakah aku lebih pendek darimu? True = kamu lebih tinggi ;) dan False = aku lebih tinggi xoxoxo")
tbmu_16 = int(input("Berapa tinggi badanmu? :"))
tbktbm_16 = tb_16 < tbmu_16
apk_16 = print(tbktbm_16)

# %%
#type 2.9
umur_16 = 19
semester_16 = 2
apk_16 = print (umur_16 > 17 and semester_16 < 5)
