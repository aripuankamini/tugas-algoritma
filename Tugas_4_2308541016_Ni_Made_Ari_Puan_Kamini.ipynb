# %%
#2.12 List
enhypen_16 = ['Yang Jungwon', 'Lee Heeseung', 'Park Jongseong', 'Sim Jaeyun', 'Park Sunghoon', 'Kim Sunoo', 'Ni-Ki']

apk_16 = print ("        ",enhypen_16[0], "     ")
apk_16 = print ("        and his members        ")
apk_16 = print ("_______________________________")
apk_16 = print (enhypen_16)
apk_16 = print (" ")
apk_16 = print ("lihat nama alias memberdeul yuk!")
apk_16 = print (" ")
enhypen_16[0:7] = 'Jakah', 'Heli', 'Jaan', 'Jino', 'Solon', 'Shion', 'Noah'
apk_16 = print (enhypen_16)
apk_16 = print ("jumlah member enhypen adalah ",len(enhypen_16))

# %%
#2.13 Metoda List
seventeen_16 = ['Choi Seungcheol', 'Yoon Jeonghan', 'Hong Jisoo', 'Moon Junhuiu', 'Kwon Soonyoung', 'Jeon Wonwoo', 'Lee Jihoon', 'Xu Minghao', 'Kim Mingyu', 'Lee Seokmin', 'Boo Seungkwan', 'Choi Hansol', 'Lee Chan']
carat_16 = print("seventeen carat")
crt_16 = int(input("member seventeen nomor berapakah biasku?(harus antara 0-12 ya!) : "))
crts_16 =print ("Biasmu adalah",seventeen_16[crt_16], "congrats carats!")
apk_16 =print(" ")
seventeen_16.insert (13, 'SEVENTEEN CARATS')
print ("Ayoo fanchant carat!", seventeen_16)

# %%
#2.14 For loop

angka_16 = [17,8,19,45,78]
for n in angka_16:
    print (n)
    
negaraku_16 = 'Indonesia'    
for abjad in negaraku_16:
    print (abjad)
