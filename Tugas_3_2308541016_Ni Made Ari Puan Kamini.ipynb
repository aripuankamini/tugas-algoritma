# %%
#2.10
apk_16 = print (" MARI KITA LIHAT PREDIKAT NILAIMU ^^ ")
apk_16 = print (" =================================== ")
apk_16 = print ("")
nilai_16 = int(input("Masukkan nilai yang kamu dapatkan: "))
if nilai_16 > 92 :
    print("Nilai yang kamu peroleh adalah A!")
    print("Selamat yaa, nilaimu sudah sangat memuaskan. Tolong dipertahankan ya...^^")
elif nilai_16 > 82 :
    print ("Nilai yang kamu peroleh adalah B!")
    print ("Jangan berkecil hati, nilaimu sudah bagus kok. Ayoo ditingkatkan!")
elif nilai_16 > 72 :
    print ("Nilai yang kamu peroleh adalah C!")
    print ("Wahh nilaimu ada direntang cukup nih! Belajar lebih giat ya...")
elif nilai_16 > 62 :
    print ("Nilai yang kamu peroleh adalah D! Belajar lebih giat ya!")
    print ("WOWOWO sepertinya kamu perlu berlatih lagi.")
else :
    print ("Nilai kamu E! Yahh, sepertinya kamu harus coba lagi di tahun depan ya...")

# %%
#2.11
apk_16 = int(input ("Input sebuah angka kurang dari 10: "))

while apk_16 <= 10:
    apk_16 += 1
    print (apk_16, end=" ")

print ("Batasan kami adalah 10^^")

# %%
#kombinasi penggunaan if dan while

bil_16 = int(input("Masukan sebuah bilangan: "))
while bil_16 > 0:
    if (bil_16%2) == 0:
        print (bil_16 , end=" ")
    bil_16 = bil_16-1
if bil_16 < 0:
    print ("Bilangan yang kamu masukan negatif!")

# %%
end_16 = True
while end_16 :
    umur_16 = int(input("Masukkan umurmu ditahun ini :"))
    tahunLahir_16 = 2024 - umur_16
    if umur_16 > 2024:
        print ("Kamu lahir pada tahun",tahunLahir_16*-1, "SM")
    else:
        print ("Kamu lahir di tahun ", tahunLahir_16)
        
    lanjut_16 = str(input("lagi? ya/tidak: "))
    if lanjut_16.lower() == "tidak":
        end_16 = False
        
print("")
print ("Terima kasih atas waktunya!")

# %%
apk_16 = print ("Mari hitung Berat Badan Idealmu")
apk_16 = print ("Perhitungan menggunakan rumus Broca. Kamu perlu memberitahu jenis kelaminmu!")
print ("")

finish_16 = True
while finish_16 :
    tinggi_16 = float(input("Masukkan tinggi badanmu dalam centi meter (cm): "))
    berat_16 = float(input("Masukkan berat badanmu dalam kilogram (kg): "))
    gender_16 = str(input("Apa jenis kelaminmu? (Perempuan/Laki-laki)"))
    tinggidikurang_16 = tinggi_16 - 100
    if gender_16 == "Perempuan" or gender_16 == "perempuan" :
        ideal = tinggidikurang_16-tinggidikurang_16*0.15
        if berat_16 == ideal:
            print("Berat badanmu sudah ideal!")
        elif berat_16 < ideal:
            print("Berat badanmu terlalu kecil! Ayoo naikkan berat badanmu. Berat badan idealmu adalah ", ideal, "kg")
        else :
            print("Berat badanmu sudah over nih! Ayoo olahraga lebih rajin lagi. Berat badan idealmu adalah ", ideal, "kg")
    elif gender_16 == "Laki-laki" or gender_16== "laki-laki" :
        ideal = tinggidikurang_16-tinggidikurang_16*0.1
        if berat_16 == ideal:
            print("Berat badanmu sudah ideal!")
        elif berat_16 < ideal:
            print("Berat badanmu terlalu kecil! Ayoo naikkan berat badanmu. Berat badan idealmu adalah ", ideal, "kg")
        else :
            print("Berat badanmu sudah over nih! Ayoo olahraga lebih rajin lagi. Berat badan idealmu adalah ", ideal, "kg")
    else :
        print ("Gendermu tidak bisa sistem definisikan!")
    lanjut_16 = input("Kamu mau menghitung lagi? (ya/tidak): ")
    if lanjut_16.lower() == "tidak":
        finish_16 = False
apk_16 = print ("")
apk_16 = print ("terima kasih ^^")

# %%
selesai =  False
while not selesai:
    angka = int(input("masukkan angka :"))
    if angka % 2 == 0 :
        print ("genap")
    else:
        print ("ganjil")
    lanjut = str(input("lanjut? ya/tidak: "))
    if lanjut.lower() == "tidak":
        selesai = True
print ("keut")
