# %%
#contoh dipapan tulis
import numpy as np
import matplotlib.pyplot as plt

a_16 = 1
b_16 = 2
c_16 = -1
d_16 = 4

m_16 = (a_16-c_16)/(b_16-d_16)

x_16 = np.arange(-2,2,0.01)
plt.plot(x_16, m_16*(x_16-a_16)+b_16)
plt.show()

# %%
#contoh diWA
import numpy as np
import matplotlib.pyplot as plt

# Persamaan garis pertama melewati titik (a,b) dan (c,d)
a=1 #Titik (a,b)
b=1
c=2 #Titik (c,d)
d=2
m1=(d-b)/(c-a)
print("Gradien garis pertama adalah {}".format(m1))
print("Persamaan garis pertama adalah y={}x+{} ".format(m1,-m1*a+b))
#y1 = m1*(x-a)+b

# Persamaan garis pertama kedua melewati titik (e,f) dan (g,h)
e=1 #Titik (e,f)
f=1
g=2  #Titik (g,h)
h=-2
m2=(h-f)/(g-e)
print("Gradien garis ke dua adalah {}".format(m2))
print("Persamaan garis kedua adalah y={}x+{} ".format(m2,-m2*e+f))
#y2=m2*(x-e)+f

if m1==m2:
    print("Gradiennya sama lho, jadi kemungkinannya ga ada solusi atau solusinya banyak.")
else:
    # Titik potong kedua garis pada (tp_x,tp_y)
    tp_x = (m1*a-b-m2*e+f)/(m1-m2)
    tp_y = m2*(tp_x-e)+f

    print("Titik potong untuk adalah ({},{})".format(tp_x,tp_y))

    x=np.arange(tp_x-5,tp_x+5,0.01)
    plt.figure(figsize=(4,4),dpi=500)
    
    plt.plot(x,m1*(x-a)+b,color='red',label='y={}x+{}'.format(m1,-m1*a+b))
    plt.plot(x,m2*(x-e)+f,color='blue',label='y={}x+{}'.format(m2,-m2*e+f))
    plt.plot(tp_x,tp_y,color='green',marker='o',markersize=4)
    plt.legend(loc='best')
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Persamaan garis pertama melewati titik (a,b) dan (c,d)
a=-1 #Titik (a,b)
b=0
c=2 #Titik (c,d)
d=-2
m1=(d-b)/(c-a)
print("Gradien garis pertama adalah {:.2f}".format(m1))
if -m1*a+b>0:
    print("Persamaan garis pertama adalah y={:.2f}x+{:.2f} ".format(m1,-m1*a+b))
else:
    print("Persamaan garis pertama adalah y={:.2f}x{:.2f} ".format(m1,-m1*a+b))
#y1 = m1*(x-a)+b

# Persamaan garis kedua melewati titik (e,f) dan (g,h)
e=5 #Titik (e,f)
f=0
g=-5  #Titik (g,h)
h=-20
m2=(h-f)/(g-e)
print("Gradien garis ke dua adalah {:.2f}".format(m2))
if -m2*e+f>0:
    print("Persamaan garis kedua adalah y={:.2f}x+{:.2f} ".format(m2,-m2*e+f))
else:
    print("Persamaan garis kedua adalah y={:.2f}x{:.2f} ".format(m2,-m2*e+f))
#y2=m2*(x-e)+f

if m1==m2:
    print("Gradiennya sama lho, jadi kemungkinannya ga ada solusi atau solusinya banyak.")
else:
    # Titik potong kedua garis pada (tp_x,tp_y)
    tp_x = (m1*a-b-m2*e+f)/(m1-m2)
    tp_y = m2*(tp_x-e)+f

    print("Titik potong kedua garis adalah ({:.2f},{:.2f})".format(tp_x,tp_y))

    x=np.arange(tp_x-10,tp_x+10,0.01)
    plt.figure(figsize=(4,4),dpi=500)
    if -m1*a+b>0:
        plt.plot(x,m1*(x-a)+b,color='red',label='y={:.2f}x+{:.2f}'.format(m1,-m1*a+b))
    else:
        plt.plot(x,m1*(x-a)+b,color='red',label='y={:.2f}x{:.2f}'.format(m1,-m1*a+b))
    if -m2*e+f>0:
        plt.plot(x,m2*(x-e)+f,color='blue',label='y={:.2f}x+{:.2f}'.format(m2,-m2*e+f))
    else:
        plt.plot(x,m2*(x-e)+f,color='blue',label='y={:.2f}x{:.2f}'.format(m2,-m2*e+f))
        
    plt.plot(tp_x,tp_y,color='green',marker='o',markersize=4)
    plt.legend(loc='best')
    plt.show()

# %%
#2.22 Matplotlib
import numpy as np
import matplotlib.pyplot as plt
apk_16 = print("Mencaari Persamaan Garis Menggunakan Dua Titik")
apk_16 = print("______________________________________________")

print(" ")

titikx1_16 = int(input("Masukkan titik x pertama: ")) #input untuk titik (x1, y1)
titiky1_16 = int(input("Masukkan titik y pertama: "))
titikx2_16 = int(input("Masukkan titik x kedua : "))  #input untuk titik (x2, y2)
titiky2_16 = int(input("Masukkan titik y kedua : "))

apk_16 = print(f'Titik pertama ({titikx1_16}, {titiky1_16}), dan titik kedua ({titikx2_16}, {titiky2_16})') #menampilkan kedua koordinat yang telah diinput tadi


m_16 = (titikx1_16 - titikx2_16)/(titiky1_16 - titiky2_16) #mencari gradien
print(f'Gradien dari kedua titik tesebut adalah {m_16}')  #menampilkan gradien
print(f'Persamaan garis pertama y = {m1_16}x + {(m1_16*titikx1_16)*-1 + titiky1_16}') #menampilkan persamaan garis
      
x_16 = np.arange(-2,2,0.01) 
plt.plot(x_16, m_16*(x_16 - titikx1_16)+titiky1_16, 'b--') #b-- => b untuk warna garis, -- untuk jenis garisnya 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

apk_16 = print ("mencari persamaan garis menggunakan gardien dan sebuah titik yang diketahui")
apk_16 = print ("---------------------------------------------------------------------------")
ask_16 = input("Apakah gradien yang diketahui dalam bentuk bilangan bulat? (y/n)") #untuk memastikan input dari user adalah integer

if ask_16.lower() == "y":
    m_16 = float(input("Masukkan gradien yang diketahui (untuk desimal gunakan titik '.'): "))
    tx_16 = float(input("Masukkan koordinat titik x : "))
    ty_16 = float(input('Masukkan koordinat titik y : '))
    #menampilkan gradien, koordinat, dan persamaan garis yang telah diinput user
    print("persamaan garis dengan gradien", m_16, "dan pada koordinat titik (",{tx_16},",",{ty_16},") adalah y = {:.2f}x+{:.2f}".format(m_16, -m_16*tx_16+ty_16))
    x_16 = np.arange(tx_16-5,tx_16+5,0.01) 
    plt.plot(x_16, m_16*(x_16 - tx_16)+ty_16, 'b--', label = 'y = {:.2f}x+{:.2f}'.format(m_16, -m_16*tx_16+ty_16)) #b-- => b untuk warna garis, -- untuk jenis garisnya 
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend(loc = 'best')
    plt.grid('grid', linestyle='-', color = 'grey')
    plt.show() #menampilkan grafik persamaan garis
elif ask_16.lower() == "n" : #jika gradien bukan integer maka dikonversi menjadi integer terlebih dahulu
    pembilang_16 = int(input ("Masukkan nilai pembilang pada gradien : "))
    penyebut_16 = int(input("Masukkan nilai penyebut pada gradien : "))
    m_16 = pembilang_16/penyebut_16 #menghitung gradien jika berbentuk pecahan
    tx_16 = float(input("Masukkan koordinat titik x : "))
    ty_16 = float(input('Masukkan koordinat titik y : '))
    print("persamaan garis dengan gradien", m_16, "dan pada koordinat titik (",{tx_16},",",{ty_16},") adalah y = {:.2f}x+{:.2f}".format(m_16, -m_16*tx_16+ty_16))
    x_16 = np.arange(tx_16-5,tx_16+5,0.01) 
    plt.plot(x_16, m_16*(x_16 - tx_16)+ty_16, 'b--', label = 'y = {:.2f}x+{:.2f}'.format(m_16, -m_16*tx_16+ty_16)) #b-- => b untuk warna garis, -- untuk jenis garisnya 
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend(loc = 'best')
    plt.grid('grid', linestyle='-', color = 'grey')
    plt.show() #menampilkan grafik
else :
    print ("Masukkan anda salah! Terima Kasih!")

# %%
import numpy as np
import matplotlib.pyplot as plt
apk_16 = print("Mencaari 2 Persamaan Garis Menggunakan Dua Titik")
apk_16 = print("________________________________________________")

print(" ")
#titik persamaan garis yang pertama
titikx1_16 = int(input("Masukkan titik x pertama: ")) #input koordinat (x1,y1)
titiky1_16 = int(input("Masukkan titik y pertama: "))
titikx2_16 = int(input("Masukkan titik x kedua : "))  #input koordinat (y1,y2)
titiky2_16 = int(input("Masukkan titik y kedua : "))
print(" ")
#titik persamaan garis yang kedua
titikx3_16 = int(input("Masukkan titik x pertama: "))  #input koordinat (x3,y3)
titiky3_16 = int(input("Masukkan titik y pertama: "))
titikx4_16 = int(input("Masukkan titik x kedua : "))   #input koordinat (x4,y4)
titiky4_16 = int(input("Masukkan titik y kedua : "))
print(" ")
#menampilkan titik-titik yang telah diinput sebelumnya
apk_16 = print(f'Titik pertama ({titikx1_16}, {titiky1_16}), dan titik kedua ({titikx2_16}, {titiky2_16})')
apk_16 = print(f'Titik ketiga ({titikx3_16}, {titiky3_16}), dan titik keempat ({titikx4_16}, {titiky4_16})')

#mencari gradien
m1_16 = (titikx1_16 - titikx2_16)/(titiky1_16 - titiky2_16)
print(f'Gradien dari kedua titik pertama  adalah {m1_16}')  #menampilkan gradien 1
persamaan1_16 = print(f'Persamaan garis pertama y = {m1_16}x + {(m1_16*titikx1_16)*-1 + titiky1_16}') #menampilkan persamaan garis 1
m2_16 = (titikx3_16 - titikx4_16)/(titiky3_16 - titiky4_16)
print(f'Gradien dari kedua titik terakhir adalah {m2_16}') #menampilkan gradien 2
persamaan2_16 = print(f'Persamaan garis kedua y = {m2_16}x + {(m2_16*titikx3_16)*-1 + titiky3_16}') #menampilkan persamaan garis 2

#mengevaluasi gradien apakah memiliki solusi atau tidak
if m1_16 == m2_16 :
    print ("Gradiennya sama nih! Jadi kemungkinan tidak ada solusi atau solusinya sangat banyak!")
else : 
    titikpotongx_16 = (m1_16*titikx1_16-titiky1_16-m2_16*titikx3_16+titiky3_16)/(m1_16 - m2_16) #mencari titik potong x
    titikpotongy_16 = m2_16*(titikpotongx_16-titikx3_16) + titiky3_16   #mencari titik potong y
    print(f'Koordinat titik potong dari dua persamaan tersebut adalah ({titikpotongx_16}, {titikpotongy_16})') #menampilkan koorddinat titik potong

    x_16 = np.arange(titikpotongx_16-5,titikpotongx_16+5,0.01)
    plt.figure(figsize=(4,4),dpi=500)
    plt.plot(x_16, m1_16*(x_16 - titikx1_16)+titiky1_16, color = 'pink', label = 'y = {}x+{}'.format(m1_16,(m1_16*titikx1_16)*-1 + titiky1_16 ))
    plt.plot(x_16, m2_16*(x_16 - titikx3_16)+titiky3_16, color = 'blue', label = 'y = {}x+{}'.format(m2_16,(m2_16*titikx3_16)*-1 + titiky3_16 ))
    plt.plot(titikpotongx_16,titikpotongy_16, color='orange', marker='*',markersize=6) #menampilkan letak titik potong yang ditandai dengan *
    plt.title('Grafik 2 Fungsi Linear', fontdict={'fontname':'Times New Roman', 'fontsize': 14}) #mengganti font yang digunakan pada judul grafik
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend(loc='best')
    plt.grid('grid', linestyle='-', color = 'grey') #untuk menambahkan grid pada grafik
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
apk_16 = print("Mencaari 2 Persamaan Garis Menggunakan Dua Titik")
apk_16 = print("________________________________________________")

print(" ")
#titik persamaan garis yang pertama
titikx1_16 = int(input("Masukkan titik x pertama: ")) #input koordinat (x1,y1)
titiky1_16 = int(input("Masukkan titik y pertama: "))
titikx2_16 = int(input("Masukkan titik x kedua : "))  #input koordinat (y1,y2)
titiky2_16 = int(input("Masukkan titik y kedua : "))
print(" ")
#titik persamaan garis yang kedua
titikx3_16 = int(input("Masukkan titik x pertama: "))  #input koordinat (x3,y3)
titiky3_16 = int(input("Masukkan titik y pertama: "))
titikx4_16 = int(input("Masukkan titik x kedua : "))   #input koordinat (x4,y4)
titiky4_16 = int(input("Masukkan titik y kedua : "))
print(" ")
#menampilkan titik-titik yang telah diinput sebelumnya
apk_16 = print(f'Titik pertama ({titikx1_16}, {titiky1_16}), dan titik kedua ({titikx2_16}, {titiky2_16})')
apk_16 = print(f'Titik ketiga ({titikx3_16}, {titiky3_16}), dan titik keempat ({titikx4_16}, {titiky4_16})')

#mencari gradien
m1_16 = (titikx1_16 - titikx2_16)/(titiky1_16 - titiky2_16)
print(f'Gradien dari kedua titik pertama  adalah {m1_16}')  #menampilkan gradien 1
persamaan1_16 = print(f'Persamaan garis pertama y = {m1_16}x + {(m1_16*titikx1_16)*-1 + titiky1_16}') #menampilkan persamaan garis 1
m2_16 = (titikx3_16 - titikx4_16)/(titiky3_16 - titiky4_16)
print(f'Gradien dari kedua titik terakhir adalah {m2_16}') #menampilkan gradien 2
persamaan2_16 = print(f'Persamaan garis kedua y = {m2_16}x + {(m2_16*titikx3_16)*-1 + titiky3_16}') #menampilkan persamaan garis 2

#mengevaluasi gradien untuk mencari tahu apakah memiliki solusi atau tidak
if m1_16 == m2_16 :
    print ("Gradiennya sama nih! Jadi kemungkinan tidak ada solusi (sejajar) atau solusinya sangat banyak (berhimpit)!")
    x_16 = np.arange(titikpotongx_16-20,titikpotongx_16+20,0.01)
    plt.figure(figsize=(4,4),dpi=500)
    plt.plot(x_16, m1_16*(x_16 - titikx1_16)+titiky1_16, color = 'pink', label = 'y = {}x+{}'.format(m1_16,(m1_16*titikx1_16)*-1 + titiky1_16 ))
    plt.plot(x_16, m2_16*(x_16 - titikx3_16)+titiky3_16, color = 'blue', label = 'y = {}x+{}'.format(m2_16,(m2_16*titikx3_16)*-1 + titiky3_16 ))
    plt.title('Grafikmu!', fontdict={'fontname':'Times New Roman', 'fontsize': 14}) #mengganti font yang digunakan pada judul grafik
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend(loc='best')
    plt.show() #menampilkan jenis grafik yang dihasilkan apakah merupakan garis sejejar atau berhimpit (jika berhimpit maka hanya satu warna yag terlihat)
else : #karena m1 =/= m2 sehingga memiliki solusi tunggal
    titikpotongx_16 = (m1_16*titikx1_16-titiky1_16-m2_16*titikx3_16+titiky3_16)/(m1_16 - m2_16) #mencari titik potong x
    titikpotongy_16 = m2_16*(titikpotongx_16-titikx3_16) + titiky3_16   #mencari titik potong y
    print(f'Koordinat titik potong dari dua persamaan tersebut adalah ({titikpotongx_16}, {titikpotongy_16})') #menampilkan koorddinat titik potong

    x_16 = np.arange(titikpotongx_16-5,titikpotongx_16+5,0.01)
    plt.figure(figsize=(4,4),dpi=500)
    plt.plot(x_16, m1_16*(x_16 - titikx1_16)+titiky1_16, color = 'pink', label = 'y = {}x+{}'.format(m1_16,(m1_16*titikx1_16)*-1 + titiky1_16 ))
    plt.plot(x_16, m2_16*(x_16 - titikx3_16)+titiky3_16, color = 'blue', label = 'y = {}x+{}'.format(m2_16,(m2_16*titikx3_16)*-1 + titiky3_16 ))
    plt.plot(titikpotongx_16,titikpotongy_16, color='orange', marker='*',markersize=6)
    plt.title('Grafik 2 Fungsi Linear', fontdict={'fontname':'Times New Roman', 'fontsize': 14}) #mengganti font yang digunakan pada judul grafik
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend(loc='best')
    plt.show()

# %%
#ini versi yang bisa tau kalau gradiennya sama apakah garisnya berhimpit atau sejajar
import numpy as np
import matplotlib.pyplot as plt
apk_16 = print("Mencaari 2 Persamaan Garis Menggunakan Dua Titik")
apk_16 = print("________________________________________________")

print(" ")
#titik persamaan garis yang pertama
titikx1_16 = int(input("Masukkan titik x pertama: ")) #input koordinat (x1,y1)
titiky1_16 = int(input("Masukkan titik y pertama: "))
titikx2_16 = int(input("Masukkan titik x kedua : "))  #input koordinat (y1,y2)
titiky2_16 = int(input("Masukkan titik y kedua : "))
print(" ")
#titik persamaan garis yang kedua
titikx3_16 = int(input("Masukkan titik x pertama: "))  #input koordinat (x3,y3)
titiky3_16 = int(input("Masukkan titik y pertama: "))
titikx4_16 = int(input("Masukkan titik x kedua : "))   #input koordinat (x4,y4)
titiky4_16 = int(input("Masukkan titik y kedua : "))
print(" ")
#menampilkan titik-titik yang telah diinput sebelumnya
apk_16 = print(f'Titik pertama ({titikx1_16}, {titiky1_16}), dan titik kedua ({titikx2_16}, {titiky2_16})')
apk_16 = print(f'Titik ketiga ({titikx3_16}, {titiky3_16}), dan titik keempat ({titikx4_16}, {titiky4_16})')

#mencari gradien
m1_16 = (titikx1_16 - titikx2_16)/(titiky1_16 - titiky2_16)
print(f'Gradien dari kedua titik pertama  adalah {m1_16}')  #menampilkan gradien 1
persamaan1_16 = print(f'Persamaan garis pertama y = {m1_16}x + {(m1_16*titikx1_16)*-1 + titiky1_16}') #menampilkan persamaan garis 1
m2_16 = (titikx3_16 - titikx4_16)/(titiky3_16 - titiky4_16)
print(f'Gradien dari kedua titik terakhir adalah {m2_16}') #menampilkan gradien 2
persamaan2_16 = print(f'Persamaan garis kedua y = {m2_16}x + {(m2_16*titikx3_16)*-1 + titiky3_16}') #menampilkan persamaan garis 2

#mendefinisikan persamaan y dengan mengabaikan variabel x
y1_16 = m1_16 + (m1_16*titikx1_16)*-1 + titiky1_16
y2_16 = m2_16 + (m2_16*titikx3_16)*-1 + titiky3_16
#mengevaluasi gradien untuk mencari tahu apakah memiliki solusi atau tidak
if m1_16 == m2_16 : 
    print ("Gradiennya sama nih! Jadi kemungkinan tidak ada solusi (sejajar) atau solusinya sangat banyak (berhimpit)!")
    if y1_16 == y2_16: #mencari tahu apakah kedua garis tersebut berhimpit atau sejajar
        print("Wahhh Kedua garis berhimpit! Jadi Persamaan Tersebut Memiliki Banyak Solusi")
    else : 
        print("Tampaknya Kedua Garismu Sejajar! Yahh, Persamaanmu Tidak Memiliki Solusi nih")
    x_16 = np.arange(titikpotongx_16-20,titikpotongx_16+20,0.01)
    plt.figure(figsize=(4,4),dpi=200)
    plt.plot(x_16, m1_16*(x_16 - titikx1_16)+titiky1_16, color = 'pink', label = 'y = {}x+{}'.format(m1_16,(m1_16*titikx1_16)*-1 + titiky1_16 ))
    plt.plot(x_16, m2_16*(x_16 - titikx3_16)+titiky3_16, color = 'skyblue', label = 'y = {}x+{}'.format(m2_16,(m2_16*titikx3_16)*-1 + titiky3_16 ))
    plt.fill_between(x_16,m1_16*(x_16 - titikx1_16)+titiky1_16, m2_16*(x_16 - titikx3_16)+titiky3_16, interpolate=True, alpha=0.2, color='grey')  # Mengarsir daerah di antara kedua garis
    plt.title('Grafik Dua Fungsi Linear', fontdict={'fontname':'Times New Roman', 'fontsize': 14}) #mengganti font yang digunakan pada judul grafik
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend(loc='best')
    plt.show() #menampilkan jenis grafik yang dihasilkan apakah merupakan garis sejejar atau berhimpit (jika berhimpit maka hanya satu warna yag terlihat)
else : #karena m1 =/= m2 sehingga memiliki solusi tunggal
    titikpotongx_16 = (m1_16*titikx1_16-titiky1_16-m2_16*titikx3_16+titiky3_16)/(m1_16 - m2_16) #mencari titik potong x
    titikpotongy_16 = m2_16*(titikpotongx_16-titikx3_16) + titiky3_16   #mencari titik potong y
    print(f'Koordinat titik potong dari dua persamaan tersebut adalah ({titikpotongx_16}, {titikpotongy_16})') #menampilkan koorddinat titik potong

    x_16 = np.arange(titikpotongx_16-5,titikpotongx_16+5,0.01)
    plt.figure(figsize=(4,4),dpi=200)
    plt.plot(x_16, m1_16*(x_16 - titikx1_16)+titiky1_16, color = 'pink', label = 'y = {}x+{}'.format(m1_16,(m1_16*titikx1_16)*-1 + titiky1_16 ))
    plt.plot(x_16, m2_16*(x_16 - titikx3_16)+titiky3_16, color = 'blue', label = 'y = {}x+{}'.format(m2_16,(m2_16*titikx3_16)*-1 + titiky3_16 ))
    plt.fill_between(x_16,m1_16*(x_16 - titikx1_16)+titiky1_16, m2_16*(x_16 - titikx3_16)+titiky3_16, interpolate=True, alpha=0.2, color='grey')  # Mengarsir daerah di antara kedua garis
    plt.plot(titikpotongx_16,titikpotongy_16, color='orange', marker='*',markersize=6) #memberi tanda pada titik potong
    plt.title('Grafik 2 Fungsi Linear', fontdict={'fontname':'Times New Roman', 'fontsize': 14}) #mengganti font yang digunakan pada judul grafik
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend(loc='best')
    plt.show()
