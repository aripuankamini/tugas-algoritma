# %%
print("   SIM JAEYUN! SIM JAEYUN!   ") 
print("_____________________________")

# %%
def tampilJumlah(a_16,b_16):
    jumlah = a_16 + b_16
    return jumlah

a_16 = int(input("angka pertama = "))
b_16 = int(input("angka kedua = "))
print("Hasil dari penjumlahan = ",tampilJumlah (a_16,b_16))
tampilJumlah (a_16,b_16)

# %%
def tampilLuas(a_16,t_16):
    Luas = (a_16*t_16)/2
    return Luas
a_16 = int (input("panjang alas segitiga adalah "))
t_16 = int (input("tinggi segitiga adalah "))
print("Luas segitiga adalah ",tampilLuas (a_16,t_16), "cm")
tampilLuas (a_16,t_16)

# %%
apk_16 = print("Kali ini mari kita menghitung faktorial dari sebuah bilangan!")

bil_16 = int(input("masukkan sebuah bilangan yang ingin kamu ketahui faktorial dari bilangan tersebut :"))

def faktorial (bil_16):
    if bil_16 == 0 :
        return 1
    else :
        return bil_16 * faktorial(bil_16 - 1)
    
print ("Hasil dari", bil_16 , "! =" , faktorial(bil_16))

# %%
apk_16 = print ("        Hai, ayoo kita menghitung faktorial!         ")
apk_16 = print ("Kali ini versi yang memiliki batas ya... dari 0-20 ^^")
apk_16 = print ("______________________________________________________")
apk_16 = print ("")

bil_16 = int(input ("masukkan sebuah bilangan diantara 0-20 ya: "))

def faktorial (bil_16) :
    if bil_16 == 0 :
        return 1
    else :
        return bil_16*faktorial(bil_16 -1)

if bil_16 > 20 :
    print ("Bilangan yang kamu masukkan terlalu besar nih...")
elif bil_16 < 0 :
    print ("Maaf bilangan yang kamu masukkan tidak dapat program proses. Tolong masukkan bilangan positif yaa")
else :
    print ("Hasil dari", bil_16 , "! = " , faktorial(bil_16))

# %%
apk_16 = print("HAI! Selamat datang di program Ari!")
apk_16 = print("     Mari kita bermain sejenak     ")
apk_16 = print("___________________________________")

apk_16 = print("Kita akan bermain tebak-tebakan angka yuk!")

import random 
tebakanku_16 = random.randint(1,100)

batas_percobaan_16 = int(input("kamu yakin berhasil menebak dalam berapa kali nih? : "))
apk_16 = print("apa yang kamu yakini akan menjadi jumlah kesempatanmu ya!")

for percobaan in range (batas_percobaan_16) :
    tebakan_16 = int(input ("masukkan sebuah angka : ")) 
    
    if tebakan_16 == tebakanku_16 :
        print("WoW kamu hebat! tebakanmu benar!")
        
        break
    elif tebakan_16 <= tebakanku_16 :
        print("Sayang sekali, tebakanmu terlalu kecil ^^")
    elif tebakan_16 >= tebakanku_16 :
        print("Sayang sekali, tebakanmu terlalu besar ^^")
else :
    print ("YAHHHH, kesempatan yang kamu miliki telah habis...")


#mohon maaf pak, ini saya beberapa ada liat google untuk code-nya tapi tidak saya copy-paste melainkan saya modifikasi
